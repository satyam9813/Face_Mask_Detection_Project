# %% [markdown]
# # Implementation of Model

# %%
# !pip install pygame
# Out:
# Requirement already satisfied: pygame in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (2.6.0)

# %%
from keras.models import load_model
import cv2
import numpy as np
from pygame import mixer

mixer.init()
sound = mixer.Sound('warning2.wav')
model = load_model('my_model.h5')
face_clsfr=cv2.CascadeClassifier('haarcascade_frontalface_default.xml')
source=cv2.VideoCapture(0)
labels_dict={0:'Without Mask',1:'With Mask'}
color_dict={0:(0,0,255),1:(0,255,0)}

while(True):

    ret,img=source.read()
    gray=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
    faces=face_clsfr.detectMultiScale(gray,1.3,5)  

    for x,y,w,h in faces:
    
        face_img=gray[y:y+w,x:x+w]
        resized=cv2.resize(face_img,(100,100))
        normalized=resized/255.0
        reshaped=np.reshape(normalized,(1,100,100,1))
        result=model.predict(reshaped)

        label=np.argmax(result,axis=1)[0]
      
        cv2.rectangle(img,(x,y),(x+w,y+h),color_dict[label],2)
        cv2.rectangle(img,(x,y-40),(x+w,y),color_dict[label],-1)
        cv2.putText(img, labels_dict[label], (x, y-10),cv2.FONT_HERSHEY_SIMPLEX,0.8,(255,255,255),2)
        
        if(labels_dict[label] =='With Mask'):
            print("With Mask (No Warning)")
        elif(labels_dict[label] =='Without Mask'):
            print("Without Mask (Warning)") 
            sound.play()    
    cv2.imshow('LIVE',img)
    key=cv2.waitKey(1)
    
    if(key==27):
        break
        
cv2.destroyAllWindows()
source.release()
# Out:
# pygame 2.6.0 (SDL 2.28.4, Python 3.12.0)
# Hello from the pygame community. https://www.pygame.org/contribute.html
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 355ms/step
# With Mask (No Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# With Mask (No Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# With Mask (No Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Without Mask (Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# With Mask (No Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# With Mask (No Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# With Mask (No Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# With Mask (No Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# With Mask (No Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# With Mask (No Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# With Mask (No Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# With Mask (No Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# With Mask (No Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# With Mask (No Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# With Mask (No Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# With Mask (No Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# With Mask (No Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# With Mask (No Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# With Mask (No Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# With Mask (No Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# With Mask (No Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# With Mask (No Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# With Mask (No Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# With Mask (No Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# With Mask (No Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# With Mask (No Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# With Mask (No Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# With Mask (No Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# With Mask (No Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# With Mask (No Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# With Mask (No Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# With Mask (No Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# With Mask (No Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# With Mask (No Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# With Mask (No Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# With Mask (No Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# With Mask (No Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# With Mask (No Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# With Mask (No Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# With Mask (No Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# With Mask (No Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# With Mask (No Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# With Mask (No Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# With Mask (No Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# Without Mask (Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# With Mask (No Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# With Mask (No Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# With Mask (No Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# With Mask (No Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# With Mask (No Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# With Mask (No Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# With Mask (No Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# With Mask (No Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# With Mask (No Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# With Mask (No Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# With Mask (No Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# With Mask (No Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# With Mask (No Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# With Mask (No Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# With Mask (No Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# With Mask (No Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# With Mask (No Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# Without Mask (Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# Without Mask (Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# Without Mask (Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# With Mask (No Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# With Mask (No Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# Without Mask (Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# Without Mask (Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# With Mask (No Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# With Mask (No Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# Without Mask (Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Without Mask (Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# With Mask (No Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# With Mask (No Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# With Mask (No Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# With Mask (No Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# With Mask (No Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# With Mask (No Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# With Mask (No Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# With Mask (No Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# With Mask (No Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# With Mask (No Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# With Mask (No Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# With Mask (No Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# Without Mask (Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# With Mask (No Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# With Mask (No Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# With Mask (No Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# With Mask (No Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# With Mask (No Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# With Mask (No Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# With Mask (No Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# With Mask (No Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# With Mask (No Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# With Mask (No Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# With Mask (No Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# With Mask (No Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# Without Mask (Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# With Mask (No Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# Without Mask (Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Without Mask (Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# With Mask (No Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# Without Mask (Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# Without Mask (Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# With Mask (No Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# Without Mask (Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# With Mask (No Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# With Mask (No Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# Without Mask (Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# With Mask (No Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# With Mask (No Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# Without Mask (Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# Without Mask (Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# With Mask (No Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# Without Mask (Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Without Mask (Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# Without Mask (Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# With Mask (No Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# With Mask (No Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# With Mask (No Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# With Mask (No Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# Without Mask (Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# Without Mask (Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# Without Mask (Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# With Mask (No Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# With Mask (No Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# With Mask (No Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# Without Mask (Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# With Mask (No Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# With Mask (No Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# With Mask (No Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# With Mask (No Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# With Mask (No Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# With Mask (No Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# With Mask (No Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# Without Mask (Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# Without Mask (Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# Without Mask (Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# With Mask (No Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# Without Mask (Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# Without Mask (Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# Without Mask (Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# Without Mask (Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# Without Mask (Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# Without Mask (Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Without Mask (Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# Without Mask (Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# Without Mask (Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# With Mask (No Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# With Mask (No Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# Without Mask (Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# With Mask (No Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# Without Mask (Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# With Mask (No Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# With Mask (No Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# With Mask (No Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# With Mask (No Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Without Mask (Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# Without Mask (Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# Without Mask (Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# Without Mask (Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# With Mask (No Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# With Mask (No Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# Without Mask (Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# With Mask (No Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# Without Mask (Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# Without Mask (Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# With Mask (No Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# Without Mask (Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# Without Mask (Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# With Mask (No Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# With Mask (No Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# With Mask (No Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# With Mask (No Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# With Mask (No Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# With Mask (No Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# With Mask (No Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# With Mask (No Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# With Mask (No Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# With Mask (No Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# With Mask (No Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# With Mask (No Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# With Mask (No Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# With Mask (No Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# With Mask (No Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# With Mask (No Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# Without Mask (Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# Without Mask (Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# With Mask (No Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# Without Mask (Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# Without Mask (Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# With Mask (No Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# With Mask (No Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# With Mask (No Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# With Mask (No Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# With Mask (No Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# With Mask (No Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# Without Mask (Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# Without Mask (Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# With Mask (No Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# With Mask (No Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# With Mask (No Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# With Mask (No Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# With Mask (No Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# With Mask (No Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Without Mask (Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# With Mask (No Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# With Mask (No Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# With Mask (No Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# With Mask (No Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# With Mask (No Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# With Mask (No Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# With Mask (No Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# With Mask (No Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# With Mask (No Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# With Mask (No Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# With Mask (No Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# With Mask (No Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# With Mask (No Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# With Mask (No Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# With Mask (No Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# With Mask (No Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# With Mask (No Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# Without Mask (Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# Without Mask (Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# Without Mask (Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# Without Mask (Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# Without Mask (Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Without Mask (Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# With Mask (No Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# Without Mask (Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# Without Mask (Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# Without Mask (Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# Without Mask (Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Without Mask (Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# Without Mask (Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# Without Mask (Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Without Mask (Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# Without Mask (Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# Without Mask (Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Without Mask (Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Without Mask (Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Without Mask (Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# Without Mask (Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# Without Mask (Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# Without Mask (Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# Without Mask (Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# Without Mask (Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# Without Mask (Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Without Mask (Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# Without Mask (Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# Without Mask (Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# With Mask (No Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Without Mask (Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# Without Mask (Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Without Mask (Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# Without Mask (Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# Without Mask (Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# With Mask (No Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# Without Mask (Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# With Mask (No Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# Without Mask (Warning)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# Without Mask (Warning)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 26
#      24 normalized=resized/255.0
#      25 reshaped=np.reshape(normalized,(1,100,100,1))
# ---> 26 result=model.predict(reshaped)
#      28 label=np.argmax(result,axis=1)[0]
#      30 cv2.rectangle(img,(x,y),(x+w,y+h),color_dict[label],2)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\utils\traceback_utils.py:118, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     116 filtered_tb = None
#     117 try:
# --> 118     return fn(*args, **kwargs)
#     119 except Exception as e:
#     120     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\backend\tensorflow\trainer.py:446, in TensorFlowTrainer.predict(self, x, batch_size, verbose, steps, callbacks)
#     441 @traceback_utils.filter_traceback
#     442 def predict(
#     443     self, x, batch_size=None, verbose="auto", steps=None, callbacks=None
#     444 ):
#     445     # Create an iterator that yields batches of input data.
# --> 446     epoch_iterator = TFEpochIterator(
#     447         x=x,
#     448         batch_size=batch_size,
#     449         steps_per_epoch=steps,
#     450         shuffle=False,
#     451         distribute_strategy=self.distribute_strategy,
#     452         steps_per_execution=self.steps_per_execution,
#     453     )
#     455     # Container that configures and calls callbacks.
#     456     if not isinstance(callbacks, callbacks_module.CallbackList):
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\backend\tensorflow\trainer.py:626, in TFEpochIterator.__init__(self, distribute_strategy, *args, **kwargs)
#     624 super().__init__(*args, **kwargs)
#     625 self._distribute_strategy = distribute_strategy
# --> 626 dataset = self.data_adapter.get_tf_dataset()
#     627 if not isinstance(dataset, tf.distribute.DistributedDataset):
#     628     dataset = self._distribute_strategy.experimental_distribute_dataset(
#     629         dataset
#     630     )
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\trainers\data_adapters\array_data_adapter.py:145, in ArrayDataAdapter.get_tf_dataset(self)
#     138     return indices
#     140 # We prefetch a single element. Computing large permutations can take
#     141 # quite a while so we don't want to wait for prefetching over an epoch
#     142 # boundary to trigger the next permutation. On the other hand, too many
#     143 # simultaneous shuffles can contend on a hardware level and degrade all
#     144 # performance.
# --> 145 indices_dataset = indices_dataset.map(permutation).prefetch(1)
#     147 def slice_batch_indices(indices):
#     148     """Convert a Tensor of indices into a dataset of batched indices.
#     149
#     150     This step can be accomplished in several ways. The most natural is
#    (...)
#     162         A Dataset of batched indices.
#     163     """
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\data\ops\dataset_ops.py:2299, in DatasetV2.map(self, map_func, num_parallel_calls, deterministic, name)
#    2295 # Loaded lazily due to a circular dependency (dataset_ops -> map_op ->
#    2296 # dataset_ops).
#    2297 # pylint: disable=g-import-not-at-top,protected-access
#    2298 from tensorflow.python.data.ops import map_op
# -> 2299 return map_op._map_v2(
#    2300     self,
#    2301     map_func,
#    2302     num_parallel_calls=num_parallel_calls,
#    2303     deterministic=deterministic,
#    2304     name=name)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\data\ops\map_op.py:37, in _map_v2(input_dataset, map_func, num_parallel_calls, deterministic, name)
#      34   if deterministic is not None and not debug_mode.DEBUG_MODE:
#      35     warnings.warn("The `deterministic` argument has no effect unless the "
#      36                   "`num_parallel_calls` argument is specified.")
# ---> 37   return _MapDataset(
#      38       input_dataset, map_func, preserve_cardinality=True, name=name)
#      39 else:
#      40   return _ParallelMapDataset(
#      41       input_dataset,
#      42       map_func,
#    (...)
#      45       preserve_cardinality=True,
#      46       name=name)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\data\ops\map_op.py:107, in _MapDataset.__init__(self, input_dataset, map_func, use_inter_op_parallelism, preserve_cardinality, use_legacy_function, name)
#     105 self._use_inter_op_parallelism = use_inter_op_parallelism
#     106 self._preserve_cardinality = preserve_cardinality
# --> 107 self._map_func = structured_function.StructuredFunctionWrapper(
#     108     map_func,
#     109     self._transformation_name(),
#     110     dataset=input_dataset,
#     111     use_legacy_function=use_legacy_function)
#     112 self._name = name
#     113 variant_tensor = gen_dataset_ops.map_dataset(
#     114     input_dataset._variant_tensor,  # pylint: disable=protected-access
#     115     self._map_func.function.captured_inputs,
#    (...)
#     118     preserve_cardinality=self._preserve_cardinality,
#     119     **self._common_args)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\data\ops\structured_function.py:265, in StructuredFunctionWrapper.__init__(self, func, transformation_name, dataset, input_classes, input_shapes, input_types, input_structure, add_to_graph, use_legacy_function, defun_kwargs)
#     258       warnings.warn(
#     259           "Even though the `tf.config.experimental_run_functions_eagerly` "
#     260           "option is set, this option does not apply to tf.data functions. "
#     261           "To force eager execution of tf.data functions, please use "
#     262           "`tf.data.experimental.enable_debug_mode()`.")
#     263     fn_factory = trace_tf_function(defun_kwargs)
# --> 265 self._function = fn_factory()
#     266 # There is no graph to add in eager mode.
#     267 add_to_graph &= not context.executing_eagerly()
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:1251, in Function.get_concrete_function(self, *args, **kwargs)
#    1249 def get_concrete_function(self, *args, **kwargs):
#    1250   # Implements PolymorphicFunction.get_concrete_function.
# -> 1251   concrete = self._get_concrete_function_garbage_collected(*args, **kwargs)
#    1252   concrete._garbage_collector.release()  # pylint: disable=protected-access
#    1253   return concrete
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:1221, in Function._get_concrete_function_garbage_collected(self, *args, **kwargs)
#    1219   if self._variable_creation_config is None:
#    1220     initializers = []
# -> 1221     self._initialize(args, kwargs, add_initializers_to=initializers)
#    1222     self._initialize_uninitialized_variables(initializers)
#    1224 if self._created_variables:
#    1225   # In this case we have created variables on the first call, so we run the
#    1226   # version which is guaranteed to never create variables.
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:696, in Function._initialize(self, args, kwds, add_initializers_to)
#     691 self._variable_creation_config = self._generate_scoped_tracing_options(
#     692     variable_capturing_scope,
#     693     tracing_compilation.ScopeType.VARIABLE_CREATION,
#     694 )
#     695 # Force the definition of the function for these arguments
# --> 696 self._concrete_variable_creation_fn = tracing_compilation.trace_function(
#     697     args, kwds, self._variable_creation_config
#     698 )
#     700 def invalid_creator_scope(*unused_args, **unused_kwds):
#     701   """Disables variable creation."""
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\eager\polymorphic_function\tracing_compilation.py:178, in trace_function(args, kwargs, tracing_options)
#     175     args = tracing_options.input_signature
#     176     kwargs = {}
# --> 178   concrete_function = _maybe_define_function(
#     179       args, kwargs, tracing_options
#     180   )
#     182 if not tracing_options.bind_graph_to_function:
#     183   concrete_function._garbage_collector.release()  # pylint: disable=protected-access
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\eager\polymorphic_function\tracing_compilation.py:283, in _maybe_define_function(args, kwargs, tracing_options)
#     281 else:
#     282   target_func_type = lookup_func_type
# --> 283 concrete_function = _create_concrete_function(
#     284     target_func_type, lookup_func_context, func_graph, tracing_options
#     285 )
#     287 if tracing_options.function_cache is not None:
#     288   tracing_options.function_cache.add(
#     289       concrete_function, current_func_context
#     290   )
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\eager\polymorphic_function\tracing_compilation.py:310, in _create_concrete_function(function_type, type_context, func_graph, tracing_options)
#     303   placeholder_bound_args = function_type.placeholder_arguments(
#     304       placeholder_context
#     305   )
#     307 disable_acd = tracing_options.attributes and tracing_options.attributes.get(
#     308     attributes_lib.DISABLE_ACD, False
#     309 )
# --> 310 traced_func_graph = func_graph_module.func_graph_from_py_func(
#     311     tracing_options.name,
#     312     tracing_options.python_function,
#     313     placeholder_bound_args.args,
#     314     placeholder_bound_args.kwargs,
#     315     None,
#     316     func_graph=func_graph,
#     317     add_control_dependencies=not disable_acd,
#     318     arg_names=function_type_utils.to_arg_names(function_type),
#     319     create_placeholders=False,
#     320 )
#     322 transform.apply_func_graph_transforms(traced_func_graph)
#     324 graph_capture_container = traced_func_graph.function_captures
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\framework\func_graph.py:1059, in func_graph_from_py_func(name, python_func, args, kwargs, signature, func_graph, add_control_dependencies, arg_names, op_return_value, collections, capture_by_value, create_placeholders)
#    1056   return x
#    1058 _, original_func = tf_decorator.unwrap(python_func)
# -> 1059 func_outputs = python_func(*func_args, **func_kwargs)
#    1061 # invariant: `func_outputs` contains only Tensors, CompositeTensors,
#    1062 # TensorArrays and `None`s.
#    1063 func_outputs = variable_utils.convert_variables_to_tensors(func_outputs)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:599, in Function._generate_scoped_tracing_options.<locals>.wrapped_fn(*args, **kwds)
#     595 with default_graph._variable_creator_scope(scope, priority=50):  # pylint: disable=protected-access
#     596   # __wrapped__ allows AutoGraph to swap in a converted function. We give
#     597   # the function a weak reference to itself to avoid a reference cycle.
#     598   with OptionalXlaContext(compile_with_xla):
# --> 599     out = weak_wrapped_fn().__wrapped__(*args, **kwds)
#     600   return out
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\data\ops\structured_function.py:231, in StructuredFunctionWrapper.__init__.<locals>.trace_tf_function.<locals>.wrapped_fn(*args)
#     230 def wrapped_fn(*args):  # pylint: disable=missing-docstring
# --> 231   ret = wrapper_helper(*args)
#     232   ret = structure.to_tensor_list(self._output_structure, ret)
#     233   return [ops.convert_to_tensor(t) for t in ret]
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\data\ops\structured_function.py:161, in StructuredFunctionWrapper.__init__.<locals>.wrapper_helper(*args)
#     159 if not _should_unpack(nested_args):
#     160   nested_args = (nested_args,)
# --> 161 ret = autograph.tf_convert(self._func, ag_ctx)(*nested_args)
#     162 ret = variable_utils.convert_variables_to_tensors(ret)
#     163 if _should_pack(ret):
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\autograph\impl\api.py:690, in convert.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     688 try:
#     689   with conversion_ctx:
# --> 690     return converted_call(f, args, kwargs, options=options)
#     691 except Exception as e:  # pylint:disable=broad-except
#     692   if hasattr(e, 'ag_error_metadata'):
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\autograph\impl\api.py:377, in converted_call(f, args, kwargs, caller_fn_scope, options)
#     374   return _call_unconverted(f, args, kwargs, options)
#     376 if not options.user_requested and conversion.is_allowlisted(f):
# --> 377   return _call_unconverted(f, args, kwargs, options)
#     379 # internal_convert_user_code is for example turned off when issuing a dynamic
#     380 # call conversion from generated code while in nonrecursive mode. In that
#     381 # case we evidently don't want to recurse, but we still have to convert
#     382 # things like builtins.
#     383 if not options.internal_convert_user_code:
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\autograph\impl\api.py:459, in _call_unconverted(f, args, kwargs, options, update_cache)
#     456   return f.__self__.call(args, kwargs)
#     458 if kwargs is not None:
# --> 459   return f(*args, **kwargs)
#     460 return f(*args)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\trainers\data_adapters\array_data_adapter.py:135, in ArrayDataAdapter.get_tf_dataset.<locals>.permutation(_)
#     131 def permutation(_):
#     132     # It turns out to be more performant to make a new set of indices
#     133     # rather than reusing the same range Tensor. (presumably because of
#     134     # buffer forwarding.)
# --> 135     indices = tf.range(num_samples, dtype=tf.int64)
#     136     if shuffle and shuffle != "batch":
#     137         indices = tf.random.shuffle(indices)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\util\dispatch.py:1260, in add_dispatch_support.<locals>.decorator.<locals>.op_dispatch_handler(*args, **kwargs)
#    1258 # Fallback dispatch system (dispatch v1):
#    1259 try:
# -> 1260   return dispatch_target(*args, **kwargs)
#    1261 except (TypeError, ValueError):
#    1262   # Note: convert_to_eager_tensor currently raises a ValueError, not a
#    1263   # TypeError, when given unexpected types.  So we need to catch both.
#    1264   result = dispatch(op_dispatch_handler, args, kwargs)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\ops\math_ops.py:2021, in range(start, limit, delta, dtype, name)
#    2018 limit = cast(limit, inferred_dtype)
#    2019 delta = cast(delta, inferred_dtype)
# -> 2021 return gen_math_ops._range(start, limit, delta, name=name)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\ops\gen_math_ops.py:8032, in _range(start, limit, delta, name)
#    8030     pass  # Add nodes to the TensorFlow graph.
#    8031 # Add nodes to the TensorFlow graph.
# -> 8032 _, _, _op, _outputs = _op_def_library._apply_op_helper(
#    8033       "Range", start=start, limit=limit, delta=delta, name=name)
#    8034 _result = _outputs[:]
#    8035 if _execute.must_record_gradient():
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\framework\op_def_library.py:796, in _apply_op_helper(op_type_name, name, **keywords)
#     791 must_colocate_inputs = [val for arg, val in zip(op_def.input_arg, inputs)
#     792                         if arg.is_ref]
#     793 with _MaybeColocateWith(must_colocate_inputs):
#     794   # Add Op to graph
#     795   # pylint: disable=protected-access
# --> 796   op = g._create_op_internal(op_type_name, inputs, dtypes=None,
#     797                              name=scope, input_types=input_types,
#     798                              attrs=attr_protos, op_def=op_def)
#     800 # `outputs` is returned as a separate return value so that the output
#     801 # tensors can the `op` per se can be decoupled so that the
#     802 # `op_callbacks` can function properly. See framework/op_callbacks.py
#     803 # for more details.
#     804 outputs = op.outputs
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\framework\func_graph.py:670, in FuncGraph._create_op_internal(self, op_type, inputs, dtypes, input_types, name, attrs, op_def, compute_device)
#     668   inp = self.capture(inp)
#     669   captured_inputs.append(inp)
# --> 670 return super()._create_op_internal(  # pylint: disable=protected-access
#     671     op_type, captured_inputs, dtypes, input_types, name, attrs, op_def,
#     672     compute_device)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\framework\ops.py:2682, in Graph._create_op_internal(self, op_type, inputs, dtypes, input_types, name, attrs, op_def, compute_device)
#    2679 # _create_op_helper mutates the new Operation. `_mutation_lock` ensures a
#    2680 # Session.run call cannot occur between creating and mutating the op.
#    2681 with self._mutation_lock():
# -> 2682   ret = Operation.from_node_def(
#    2683       node_def,
#    2684       self,
#    2685       inputs=inputs,
#    2686       output_types=dtypes,
#    2687       control_inputs=control_inputs,
#    2688       input_types=input_types,
#    2689       original_op=self._default_original_op,
#    2690       op_def=op_def,
#    2691   )
#    2692   self._create_op_helper(ret, compute_device=compute_device)
#    2693 return ret
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\framework\ops.py:1177, in Operation.from_node_def(***failed resolving arguments***)
#    1174     control_input_ops.append(control_op)
#    1176 # Initialize c_op from node_def and other inputs
# -> 1177 c_op = _create_c_op(g, node_def, inputs, control_input_ops, op_def=op_def)
#    1178 self = Operation(c_op, SymbolicTensor)
#    1179 self._init(g)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\framework\ops.py:1007, in _create_c_op(graph, node_def, inputs, control_inputs, op_def, extract_traceback)
#    1005 # pylint: disable=protected-access
#    1006 with graph._c_graph.get() as c_graph:
# -> 1007   op_desc = pywrap_tf_session.TF_NewOperation(c_graph,
#    1008                                               compat.as_str(node_def.op),
#    1009                                               compat.as_str(node_def.name))
#    1010 if node_def.device:
#    1011   pywrap_tf_session.TF_SetDevice(op_desc, compat.as_str(node_def.device))
#
# KeyboardInterrupt:
